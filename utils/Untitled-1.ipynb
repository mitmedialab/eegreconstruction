# %%
import os
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# %%
os.chdir("C:/Users/s_gue/Desktop/master_project/master_thesis")

# %%
image_dir = "./data/images/experiment_subset_easy"
out_dir = "./data/visualizations/image_experiment"
for class_name in os.listdir(image_dir):
    class_dir = image_dir + "/" + class_name
    image_paths = [class_dir + "/" + file for file in os.listdir(class_dir)]
    break
image_paths
# Out:
# ['./data/images/experiment_subset_easy/airliner/n02690373_1131.JPEG',
#  './data/images/experiment_subset_easy/airliner/n02690373_1151.JPEG',
#  './data/images/experiment_subset_easy/airliner/n02690373_1562.JPEG',
#  './data/images/experiment_subset_easy/airliner/n02690373_1563.JPEG',
#  './data/images/experiment_subset_easy/airliner/n02690373_1622.JPEG',
#  './data/images/experiment_subset_easy/airliner/n02690373_1681.JPEG',
#  './data/images/experiment_subset_easy/airliner/n02690373_1893.JPEG',
#  './data/images/experiment_subset_easy/airliner/n02690373_1903.JPEG',
#  './data/images/experiment_subset_easy/airliner/n02690373_2091.JPEG',
#  './data/images/experiment_subset_easy/airliner/n02690373_2142.JPEG',
#  './data/images/experiment_subset_easy/airliner/n02690373_2261.JPEG',
#  './data/images/experiment_subset_easy/airliner/n02690373_2349.JPEG',
#  './data/images/experiment_subset_easy/airliner/n02690373_2719.JPEG',
# ...

# %%
class_names = os.listdir(image_dir)

# %%
def plot_mean_image(image_dir, out_dir, n_columns=5):
    for class_name in os.listdir(image_dir):
        if class_name == "face":
            continue
        class_dir = image_dir + "/" + class_name
        target_size = (224,224)
        images = [Image.open(class_dir + "/" + file).resize(target_size, Image.ANTIALIAS) for file in os.listdir(class_dir)]
        mean_image = np.mean(np.stack(images, axis = 0), axis=0)
        mean_image_pil = Image.fromarray(np.uint8(mean_image))
        #mean_image_pil.show()
        plt.figure(figsize=(10,10))
        plt.title('Mean image of class: {}'.format(class_name), fontsize=30)
        plt.imshow(mean_image_pil)
        plt.axis('off')
        # # os.makedirs(output_dir_plot, exist_ok=True)
        # # plt.savefig(output_dir_plot+"/"+class_name, bbox_inches='tight')
        plt.show()

# %%
plot_mean_image(image_dir, out_dir)
# Out:
# C:\Users\s_gue\AppData\Local\Temp\ipykernel_17680\858318915.py:5: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   images = [Image.open(class_dir + "/" + file).resize(target_size, Image.ANTIALIAS) for file in os.listdir(class_dir)]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 plot_mean_image(image_dir, out_dir)
#
# Cell In[29], line 6, in plot_mean_image(image_dir, out_dir, n_columns)
#       4 target_size = (224,224)
#       5 images = [Image.open(class_dir + "/" + file).resize(target_size, Image.ANTIALIAS) for file in os.listdir(class_dir)]
# ----> 6 mean_image = np.mean(np.stack(images, axis = 0), axis=0)
#       7 mean_image_pil = Image.fromarray(np.uint8(mean_image))
#       8 #mean_image_pil.show()
#
# ...
