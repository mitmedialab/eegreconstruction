# %%
import pandas as pd
pd.set_option('display.max_columns', None)
#read .csv file
df = pd.read_csv(r"C:\Users\s_gue\Desktop\master_project\Experiment\data\442011_experiment_2023-05-27_19h57.37.580.csv")
df.head(10)
# Out:
#                                               images  group_label  label  \
# 0                                                NaN          NaN    NaN
# 1        datasets/debug_psychopy/banana/banana2.JPEG          0.0    2.0
# 2    datasets/debug_psychopy/airliner/airliner4.JPEG          1.0    9.0
# 3    datasets/debug_psychopy/airliner/airliner1.JPEG          1.0    6.0
# 4    datasets/debug_psychopy/airliner/airliner2.JPEG          1.0    7.0
# 5  datasets/debug_psychopy/jacko_lantern/lantern2...          2.0   12.0
# 6  datasets/debug_psychopy/jacko_lantern/lantern1...          2.0   11.0
# 7        datasets/debug_psychopy/banana/banana4.JPEG          0.0    4.0
# 8        datasets/debug_psychopy/banana/banana1.JPEG          0.0    1.0
# 9        datasets/debug_psychopy/banana/banana5.JPEG          0.0    5.0
#
#    trials_Image_and_Blank.thisRepN  trials_Image_and_Blank.thisTrialN  \
# 0                              NaN                                NaN
# ...

# %%
#read .xdf file
import pyxdf
data, header = pyxdf.load_xdf(r"C:\Users\s_gue\Desktop\master_project\recordings\sub-P001\ses-S001\eeg\sub-P001_ses-S001_task-Default_run-001_eeg.xdf")

# %%
data[1]["time_series"].shape
# Out:
# (18266, 17)

# %%
data[1]
# Out:
# {'info': defaultdict(list,
#              {'name': ['UN-2019.05.50'],
#               'type': ['Data'],
#               'channel_count': ['17'],
#               'nominal_srate': ['250'],
#               'channel_format': ['float32'],
#               'source_id': ['UN-2019.05.50'],
#               'version': ['1.1000000000000001'],
#               'created_at': ['211694.32653300001'],
#               'uid': ['ac6753f7-51d2-4780-9d8a-37ef361fcf7e'],
#               'session_id': ['default'],
#               'hostname': ['Sven-PC'],
#               'v4address': [None],
#               'v4data_port': ['16572'],
#               'v4service_port': ['16572'],
#               'v6address': [None],
#               'v6data_port': ['16572'],
#               'v6service_port': ['16572'],
#               'desc': [None],
#               'stream_id': 1,
#               'effective_srate': 250.20274957830625}),
#  'footer': {'info': defaultdict(list,
# ...

# %%
from bs4 import BeautifulSoup
import numpy as np
import requests
import cv2
import PIL.Image
import urllib

# %%
page = requests.get("http://www.image-net.org/api/text/imagenet.synset.geturls?wnid=n04194289")#ship synset
print(page.content)
# Out:
# b'<!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">\n<html><head>\n<title>404 Not Found</title>\n</head><body>\n<h1>Not Found</h1>\n<p>The requested URL /api/text/imagenet.synset.geturls was not found on this server.</p>\n</body></html>\n'

# %%
image_ids = {
    "jacko_lantern": "n03590841",
    "banana": "n07753592",
    "airliner": "n02690373",
    "face": "n02917067",
    "panda": "n02510455",
    "pizza": "n07873807",
    "daisy": "n11939491",
    "anemone fish": "n02606052",
}

for key in image_ids.keys():

    "https://image-net.org/data/winter21_whole/{}.tar".format(image_ids[key])
